# %%
f=((abs(9-x^2))^(1/3)) -1
plot(f, (x, -20, 20))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-c1c74e748841> in <module>
# ----> 1 f.roots()
#
# /ext/sage/sage-9.3/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:61686)()
#   11741         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11742         if len(mul) == 0 and explicit_solutions:
# > 11743             raise RuntimeError("no explicit roots found")
#   11744         else:
#   11745             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found
