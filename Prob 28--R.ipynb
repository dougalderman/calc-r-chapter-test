# %%
x <- seq(-10, 10, 0.01)
f1 <-(abs(9-x^2))^(1/3) - 1
plot(x,f1)
# Out:
# plot without title

# %%
f2 <-function(x) (abs(9-x^2))^(1/3) - 1
try(uniroot(f2, c(-3, -2)))
# Out:
# $root
# [1] -2.828427
#
# $f.root
# [1] -1.658178e-07
#
# $iter
# [1] 7
#
# $init.it
# [1] NA
#
# $estim.prec
# [1] 6.103516e-05

# %%
f2 <-function(x) (abs(9-x^2))^(1/3) - 1
try(uniroot(f2, c(2, 3)))
# Out:
# $root
# [1] 2.828427
#
# $f.root
# [1] -1.658178e-07
#
# $iter
# [1] 7
#
# $init.it
# [1] NA
#
# $estim.prec
# [1] 6.103516e-05

# %%
f2 <-function(x) (abs(9-x^2))^(1/3) - 1
try(uniroot(f2, c(-4, -3)))
# Out:
# $root
# [1] -3.162306
#
# $f.root
# [1] 5.893668e-05
#
# $iter
# [1] 6
#
# $init.it
# [1] NA
#
# $estim.prec
# [1] 6.103516e-05

# %%
f2 <-function(x) (abs(9-x^2))^(1/3) - 1
try(uniroot(f2, c(3, 4)))
# Out:
# $root
# [1] 3.162306
#
# $f.root
# [1] 5.893668e-05
#
# $iter
# [1] 6
#
# $init.it
# [1] NA
#
# $estim.prec
# [1] 6.103516e-05
